# %%
import pandas as pd

# %%
#ebt= Entertainer basic table 
#eb = entertainer breakthrough
#el = entertainer lastwork
#eac = entertainers award count

# %%
ebt = pd.read_excel("C:\\Users\\91797\\Downloads\\Entertainer - Basic Info.xlsx")
eb = pd.read_excel("C:\\Users\\91797\\Downloads\\Entertainer - Breakthrough Info.xlsx")
el = pd.read_excel("C:\\Users\\91797\\Downloads\\Entertainer - Last work Info.xlsx")
eac = pd.read_excel("C:\\Users\\91797\\Downloads\\person_awards_deatils.xlsx")

# %%
ebt.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
eb.drop('Entertainer',inplace=True,axis=1)

# %%
eb.head()
# Out:
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
el.drop('Entertainer',inplace=True,axis=1)

# %%
el.head()
# Out:
#    Year of Last Major Work (arguable)  Year of Death
# 0                                2016            NaN
# 1                                2016            NaN
# 2                                2014            NaN
# 3                                1989         1989.0
# 4                                2016            NaN

# %%
eac.drop('Entertainer',inplace=True,axis=1)

# %%
eac.head()
# Out:
#    num_nominations  num_awards  num_oscars
# 0               26          55           1
# 1               97          78           2
# 2               32          35           0
# 3               23          34          11
# 4               39          40           0

# %%
data1 = pd.concat([ebt,eb],axis=1)

# %%
data1.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
data2 = pd.concat([data1, el],axis=1)

# %%
data2.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
data = pd.concat([data2, eac],axis=1)

# %%
data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
import pandas as pd 
df = pd.DataFrame(data)

# Specify the file path
file_path = r"C:\Users\91797\Downloads\main_data.xlsx"

# Save the DataFrame to the specified location
df.to_excel(file_path, index=False)
